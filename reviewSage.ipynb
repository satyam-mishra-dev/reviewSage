# %%
# !pip install pandas textblob matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\satyam\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: textblob in c:\users\satyam\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: matplotlib in c:\users\satyam\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\satyam\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\satyam\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\satyam\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\satyam\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: nltk>=3.9 in c:\users\satyam\anaconda3\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\satyam\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\satyam\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\satyam\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\satyam\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\satyam\appdata\roaming\python\python312\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\satyam\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\satyam\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: click in c:\users\satyam\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\satyam\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\satyam\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\satyam\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.66.5)
# Requirement already satisfied: six>=1.5 in c:\users\satyam\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\users\satyam\appdata\roaming\python\python312\site-packages (from click->nltk>=3.9->textblob) (0.4.6)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Satyam\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt

# Sample data (replace with actual CSV if needed)
data = {
    "comment": [
        "I absolutely loved this video!",
        "It was okay, not the best.",
        "Worst content ever, disliked it.",
        "Great effort, keep it up!",
        "Meh, didn't like it much."
    ]
}

df = pd.DataFrame(data)

# Function to get sentiment
def get_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity
    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# Apply sentiment
df["Sentiment"] = df["comment"].apply(get_sentiment)

# View results
print(df)

# Plot
sentiment_counts = df["Sentiment"].value_counts()
sentiment_counts.plot(kind='bar', color=['green', 'grey', 'red'])
plt.title("Sentiment Analysis of YouTube Comments")
plt.xlabel("Sentiment")
plt.ylabel("Number of Comments")
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()
# Out:
#                             comment Sentiment
# 0    I absolutely loved this video!  Positive
# 1        It was okay, not the best.  Positive
# 2  Worst content ever, disliked it.  Negative
# 3         Great effort, keep it up!  Positive
# 4         Meh, didn't like it much.  Positive
